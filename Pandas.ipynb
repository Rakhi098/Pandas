# %% [markdown]
# #**Pandas**

# %% [markdown]
# **Pandas is an open source Python library for highly specialized data analysis. Currently it is the reference point that all professionals using the Python language need to study and analyze data sets for statistical purposes of analysis and decision making.**

# %%
import numpy as np
import pandas as pd

# %%
# series() for declaring series.
a = pd.Series([12, -3, 23, 9])
a
# Out:
# 0    12
# 1    -3
# 2    23
# 3     9
# dtype: int64

# %% [markdown]
# As you can see from the output of the Series, on the left there are the values in the Index, which is a
# series of labels, and on the right the corresponding values.

# %%
# including index option for assigning an array of string containing the labels.
a = pd.Series([12, -3, 23, 9], index=['a', 'b', 'c', 'd'])
a
# Out:
# a    12
# b    -3
# c    23
# d     9
# dtype: int64

# %%
a.values
# Out:
# array([12, -3, 23,  9])

# %%
a.index
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
# selecting the internal element
a[2]
# Out:
# 23

# %%
a['c']
# Out:
# 23

# %%
a[0:2]
# Out:
# a    12
# b    -3
# dtype: int64

# %%
a[-1]
# Out:
# 9

# %%
a[['b', 'd']]
# Out:
# b   -3
# d    9
# dtype: int64

# %%
# assignning Values to the element.
a[1] = 98
a
# Out:
# a    12
# b    98
# c    23
# d     9
# dtype: int64

# %%
a['c'] = -54
a
# Out:
# a    12
# b    98
# c   -54
# d     9
# dtype: int64

# %%
# defining series from numpy arrays and other series.
arr = np.array([1, 2, 3, 4, 5])
s1 = pd.Series(arr)
s1
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
arr[2] = -33
arr
# Out:
# array([  1,   2, -33,   4,   5])

# %%
s1
# Out:
# 0     1
# 1     2
# 2   -33
# 3     4
# 4     5
# dtype: int64

# %%
# filtering values
a
# Out:
# a    12
# b    98
# c   -54
# d     9
# dtype: int64

# %%
a[a > 44]
# Out:
# b    98
# dtype: int64

# %%
a[a <= 44]
# Out:
# a    12
# c   -54
# d     9
# dtype: int64

# %% [markdown]
# Operations and mathematical functions

# %%
a / 2
# Out:
# a     6.0
# b    49.0
# c   -27.0
# d     4.5
# dtype: float64

# %%
np.log(a)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# a    2.484907
# b    4.584967
# c         NaN
# d    2.197225
# dtype: float64

# %%
b = pd.Series([1, 0, 2, 1, 2, 3], index=['white', 'white', 'blue', 'green', 'green', 'yellow'])
b
# Out:
# white     1
# white     0
# blue      2
# green     1
# green     2
# yellow    3
# dtype: int64

# %%
b.unique()
# Out:
# array([1, 0, 2, 3])

# %%
b.value_counts()
# Out:
# 2    2
# 1    2
# 3    1
# 0    1
# dtype: int64

# %%
b.isin([0, 3])
# Out:
# white     False
# white      True
# blue      False
# green     False
# green     False
# yellow     True
# dtype: bool

# %%
b[b.isin([0, 3])]
# Out:
# white     0
# yellow    3
# dtype: int64

# %%
# np.NaN whenever we want to define a missing value.
b = pd.Series([5, -3, np.NaN, 14])
b
# Out:
# 0     5.0
# 1    -3.0
# 2     NaN
# 3    14.0
# dtype: float64

# %%
# isnull() and notnull() functions are very useful to identify the indexes without a value.
b.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
b.notnull()
# Out:
# 0     True
# 1     True
# 2    False
# 3     True
# dtype: bool

# %%
b[b.notnull()]
# Out:
# 0     5.0
# 1    -3.0
# 3    14.0
# dtype: float64

# %%
b[b.isnull()]
# Out:
# 2   NaN
# dtype: float64

# %% [markdown]
# ###**Series as Dictionaries**

# %%
mydict = {'red' : 2000, 'blue': 100, 'yellow': 50000, 'orange': 1435}
myseries = pd.Series(mydict)
myseries
# Out:
# red        2000
# blue        100
# yellow    50000
# orange     1435
# dtype: int64

# %%
colors = ['red', 'yellow', 'orange', 'blue', 'green']
myseries = pd.Series(mydict, index=colors)
mydict
# Out:
# {'blue': 100, 'orange': 1435, 'red': 2000, 'yellow': 50000}

# %%
# defining dataframe using DataFrame() function
data = {'color' : ['blue', 'green', 'yellow', 'red', 'white'],
        'object': ['ball', 'pen', 'pencil', 'paper', 'mug'],
        'price' : [1.2, 3.4, 5.6, 0.8, 2.4]}

# %%
frame = pd.DataFrame(data)
frame
# Out:
#     color  object  price
# 0    blue    ball    1.2
# 1   green     pen    3.4
# 2  yellow  pencil    5.6
# 3     red   paper    0.8
# 4   white     mug    2.4

# %%
# column option for selecting columns to show.
pd.DataFrame(data, columns=['object', 'price'])
# Out:
#    object  price
# 0    ball    1.2
# 1     pen    3.4
# 2  pencil    5.6
# 3   paper    0.8
# 4     mug    2.4

# %%
# if the labels are not explicitly specified within the Index array use index option.
pd.DataFrame(data, index=['one', 'two', 'three', 'four', 'five'])
# Out:
#         color  object  price
# one      blue    ball    1.2
# two     green     pen    3.4
# three  yellow  pencil    5.6
# four      red   paper    0.8
# five    white     mug    2.4

# %%
# using np.arange with index and column.
frame1 = pd.DataFrame(np.arange(16).reshape((4, 4)),
                     index=['red', 'blue', 'yellow', 'white'],
                     columns=['ball', 'pen', 'pencil', 'paper'])
frame1
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
frame.columns
# Out:
# Index(['color', 'object', 'price'], dtype='object')

# %%
frame.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
frame.values
# Out:
# array([['blue', 'ball', 1.2],
#        ['green', 'pen', 3.4],
#        ['yellow', 'pencil', 5.6],
#        ['red', 'paper', 0.8],
#        ['white', 'mug', 2.4]], dtype=object)

# %% [markdown]
# ###**Selecting Elements**

# %%
data['price']
# Out:
# [1.2, 3.4, 5.6, 0.8, 2.4]

# %%
frame[0:2]
# Out:
#    color object  price
# 0   blue   ball    1.2
# 1  green    pen    3.4

# %%
frame[1:3]
# Out:
#     color  object  price
# 1   green     pen    3.4
# 2  yellow  pencil    5.6

# %%
data['object'] [3]
# Out:
# 'paper'

# %% [markdown]
# ###**Assigning Values**

# %%
# name attribute for assigning a label.
frame.index.name = 'id'; frame.columns.name = 'item'
frame
# Out:
# item   color  object  price
# id
# 0       blue    ball    1.2
# 1      green     pen    3.4
# 2     yellow  pencil    5.6
# 3        red   paper    0.8
# 4      white     mug    2.4

# %%
frame['new'] = 12
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2   12
# 1      green     pen    3.4   12
# 2     yellow  pencil    5.6   12
# 3        red   paper    0.8   12
# 4      white     mug    2.4   12

# %%
frame['new'] = np.random.randint(0, 12)
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2   10
# 1      green     pen    3.4   10
# 2     yellow  pencil    5.6   10
# 3        red   paper    0.8   10
# 4      white     mug    2.4   10

# %%
frame['new'] = [3.9, 12.3, 9.9, 65.4, 5.5]
frame
# Out:
# item   color  object  price   new
# id
# 0       blue    ball    1.2   3.9
# 1      green     pen    3.4  12.3
# 2     yellow  pencil    5.6   9.9
# 3        red   paper    0.8  65.4
# 4      white     mug    2.4   5.5

# %%
ser = pd.Series(np.arange(5))
ser
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# dtype: int64

# %%
frame['new'] = ser
frame
# Out:
# item   color  object  price  new
# id
# 0       blue    ball    1.2    0
# 1      green     pen    3.4    1
# 2     yellow  pencil    5.6    2
# 3        red   paper    0.8    3
# 4      white     mug    2.4    4

# %%
frame['price'] [2]
# Out:
# 5.6

# %%
frame['price'] [2] = 3.3
frame
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# item   color  object  price  new
# id
# 0       blue    ball    1.2    0
# 1      green     pen    3.4    1
# 2     yellow  pencil    3.3    2
# 3        red   paper    0.8    3
# 4      white     mug    2.4    4

# %%
# membership of a value.
frame.isin([1.0, 'pen'])
# Out:
# item  color  object  price    new
# id
# 0     False   False  False  False
# 1     False    True  False   True
# 2     False   False  False  False
# 3     False   False  False  False
# 4     False   False  False  False

# %%
frame[frame.isin([1.0, 'pen'])]
# Out:
# item color object  price  new
# id
# 0      NaN    NaN    NaN  NaN
# 1      NaN    pen    NaN  1.0
# 2      NaN    NaN    NaN  NaN
# 3      NaN    NaN    NaN  NaN
# 4      NaN    NaN    NaN  NaN

# %%
# deleting a column
del frame['new']

# %%
frame
# Out:
# item   color  object  price
# id
# 0       blue    ball    1.2
# 1      green     pen    3.4
# 2     yellow  pencil    3.3
# 3        red   paper    0.8
# 4      white     mug    2.4

# %%
# filtering 
frame1[frame1 < 10]
# Out:
#         ball  pen  pencil  paper
# red      0.0  1.0     2.0    3.0
# blue     4.0  5.0     6.0    7.0
# yellow   8.0  9.0     NaN    NaN
# white    NaN  NaN     NaN    NaN

# %%
frame1[frame1 < 12]
# Out:
#         ball  pen  pencil  paper
# red      0.0  1.0     2.0    3.0
# blue     4.0  5.0     6.0    7.0
# yellow   8.0  9.0    10.0   11.0
# white    NaN  NaN     NaN    NaN

# %%
frame1[frame1 > 5]
# Out:
#         ball   pen  pencil  paper
# red      NaN   NaN     NaN    NaN
# blue     NaN   NaN     6.0    7.0
# yellow   8.0   9.0    10.0   11.0
# white   12.0  13.0    14.0   15.0

# %%
frame1[frame1 >= 5]
# Out:
#         ball   pen  pencil  paper
# red      NaN   NaN     NaN    NaN
# blue     NaN   5.0     6.0    7.0
# yellow   8.0   9.0    10.0   11.0
# white   12.0  13.0    14.0   15.0

# %%
frame1[frame1 != 5]
# Out:
#         ball   pen  pencil  paper
# red        0   1.0       2      3
# blue       4   NaN       6      7
# yellow     8   9.0      10     11
# white     12  13.0      14     15

# %% [markdown]
# ###**1.Reindexing 2.dropping 3. alignment**

# %%
# reindexing
ser = pd.Series([2, 3, 5, 7, 4], index=['one', 'two', 'three', 'four', 'five'])
ser
# Out:
# one      2
# two      3
# three    5
# four     7
# five     4
# dtype: int64

# %%
ser.reindex(['three','four','five','one' ])
# Out:
# three    5
# four     7
# five     4
# one      2
# dtype: int64

# %%
ser1 = pd.Series([1,5,3,6], index=[0, 3, 5, 6])
ser1
# Out:
# 0    1
# 3    5
# 5    3
# 6    6
# dtype: int64

# %%
# reindexing with method option.
ser1.reindex(range(6), method='ffill')
# Out:
# 0    1
# 1    1
# 2    1
# 3    5
# 4    5
# 5    3
# dtype: int64

# %%
# If you want this index value to be assigned during the interpolation, you have to use the bfill method.
ser1.reindex(range(6), method='bfill')
# Out:
# 0    1
# 1    5
# 2    5
# 3    5
# 4    3
# 5    3
# dtype: int64

# %% [markdown]
# ##**Dropping**

# %%
ser = pd.Series(np.arange(4.), index=['red','blue','yellow','white'])
ser
# Out:
# red       0.0
# blue      1.0
# yellow    2.0
# white     3.0
# dtype: float64

# %%
ser.drop('yellow')
# Out:
# red      0.0
# blue     1.0
# white    3.0
# dtype: float64

# %%
ser.drop(['blue', 'white'])
# Out:
# red       0.0
# yellow    2.0
# dtype: float64

# %%
frame = pd.DataFrame(np.arange(16).reshape((4, 4)),
                     index=['red','blue','yellow','white'],
                    columns=['ball','pen','pencil','paper'])
frame
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
frame.drop(['blue', 'yellow'])
# Out:
#        ball  pen  pencil  paper
# red       0    1       2      3
# white    12   13      14     15

# %%
# to delete column specify axis.
frame.drop(['pen', 'pencil'], axis=1)
# Out:
#         ball  paper
# red        0      3
# blue       4      7
# yellow     8     11
# white     12     15

# %% [markdown]
# ###**Functions by Element**

# %%
frame = pd.DataFrame(np.arange(16).reshape((4,4)),
                    index = ['red', 'yellow', 'brown', 'black'],
                    columns = ['ball', 'pen', 'paper', 'pencil'])
frame
# Out:
#         ball  pen  paper  pencil
# red        0    1      2       3
# yellow     4    5      6       7
# brown      8    9     10      11
# black     12   13     14      15

# %%
f = lambda x: x.max() - x.min()

# %%
# it is possible to define the function also in this way.
def f(x):
  return x.max() - x.min()

# Using the apply() function you can apply the function just defined on the DataFrame.

frame.apply(f)
# Out:
# ball      12
# pen       12
# paper     12
# pencil    12
# dtype: int64

# %%
# t if you prefer to apply the function by row instead of by column, you have to specify the axis option set to 1.

frame.apply(f, axis=1)
# Out:
# red       3
# yellow    3
# brown     3
# black     3
# dtype: int64

# %%
# apply() can returns a scalar value.
def f(x):
  return pd.Series([x.min(), x.max()], index=['min', 'max'])

frame.apply(f)
# Out:
#      ball  pen  paper  pencil
# min     0    1      2       3
# max    12   13     14      15

# %%
# Statistics Functions
frame.sum()
# Out:
# ball      24
# pen       28
# paper     32
# pencil    36
# dtype: int64

# %%
frame.mean()
# Out:
# ball      6.0
# pen       7.0
# paper     8.0
# pencil    9.0
# dtype: float64

# %%
frame.max()
# Out:
# ball      12
# pen       13
# paper     14
# pencil    15
# dtype: int64

# %%
frame.std()
# Out:
# ball      5.163978
# pen       5.163978
# paper     5.163978
# pencil    5.163978
# dtype: float64

# %%
frame.min()
# Out:
# ball      0
# pen       1
# paper     2
# pencil    3
# dtype: int64

# %%
# describe() to obtain a summary.
frame.describe()
# Out:
#             ball        pen      paper     pencil
# count   4.000000   4.000000   4.000000   4.000000
# mean    6.000000   7.000000   8.000000   9.000000
# std     5.163978   5.163978   5.163978   5.163978
# min     0.000000   1.000000   2.000000   3.000000
# 25%     3.000000   4.000000   5.000000   6.000000
# 50%     6.000000   7.000000   8.000000   9.000000
# 75%     9.000000  10.000000  11.000000  12.000000
# max    12.000000  13.000000  14.000000  15.000000

# %% [markdown]
# ###**Sorting and Ranking**

# %%
ser = pd.Series([5,0,3,8,4], index=['red','blue','yellow','white','green'])
ser
# Out:
# red       5
# blue      0
# yellow    3
# white     8
# green     4
# dtype: int64

# %%
ser.sort_index()
# Out:
# blue      0
# green     4
# red       5
# white     8
# yellow    3
# dtype: int64

# %%
ser.sort_index(ascending=False)
# Out:
# yellow    3
# white     8
# red       5
# green     4
# blue      0
# dtype: int64

# %%
frame = pd.DataFrame(np.arange(16).reshape((4,4)),
                     index=['red','blue','yellow','white'],
                     columns=['ball','pen','pencil','paper'])
frame
# Out:
#         ball  pen  pencil  paper
# red        0    1       2      3
# blue       4    5       6      7
# yellow     8    9      10     11
# white     12   13      14     15

# %%
frame.sort_index()
# Out:
#         ball  pen  pencil  paper
# blue       4    5       6      7
# red        0    1       2      3
# white     12   13      14     15
# yellow     8    9      10     11

# %%
frame.sort_index(axis=1)
# Out:
#         ball  paper  pen  pencil
# red        0      3    1       2
# blue       4      7    5       6
# yellow     8     11    9      10
# white     12     15   13      14

# %%
# The ranking is an operation closely related to sorting. The rank will be assigned starting from the lowest value to the highest value.
ser.rank()
# Out:
# red       4.0
# blue      1.0
# yellow    2.0
# white     5.0
# green     3.0
# dtype: float64

# %%
ser.rank(method='first')
# Out:
# red       4.0
# blue      1.0
# yellow    2.0
# white     5.0
# green     3.0
# dtype: float64

# %%
# By default, even the ranking follows an ascending sort. To reverse this criterion, set the ascending option to False.
ser.rank(ascending=False)
# Out:
# red       2.0
# blue      5.0
# yellow    4.0
# white     1.0
# green     3.0
# dtype: float64

# %% [markdown]
# ###**Correlation and Covariance***

# %% [markdown]
# **Two important statistical calculations are correlation and covariance, expressed in pandas by the corr() and
# cov() functions**

# %%
frame2 = pd.DataFrame([[1,4,3,6],[4,5,6,1],[3,3,1,5],[4,1,6,4]],
                   index=['red','blue','yellow','white'],
                    columns=['ball','pen','pencil','paper'])
frame2
# Out:
#         ball  pen  pencil  paper
# red        1    4       3      6
# blue       4    5       6      1
# yellow     3    3       1      5
# white      4    1       6      4

# %%
frame2.corr()
# Out:
#             ball       pen    pencil     paper
# ball    1.000000 -0.276026  0.577350 -0.763763
# pen    -0.276026  1.000000 -0.079682 -0.361403
# pencil  0.577350 -0.079682  1.000000 -0.692935
# paper  -0.763763 -0.361403 -0.692935  1.000000

# %%
frame2.cov()
# Out:
#             ball       pen    pencil     paper
# ball    2.000000 -0.666667  2.000000 -2.333333
# pen    -0.666667  2.916667 -0.333333 -1.333333
# pencil  2.000000 -0.333333  6.000000 -3.666667
# paper  -2.333333 -1.333333 -3.666667  4.666667

# %% [markdown]
# Using the method corrwith(), you can calculate the pairwise correlations between the columns or rows
# of a data frame with a Series or another DataFrame().

# %%
 frame2.corrwith(ser)
# Out:
# ball     -0.140028
# pen      -0.869657
# pencil    0.080845
# paper     0.595854
# dtype: float64

# %%
frame2.corrwith(frame)
# Out:
# ball      0.730297
# pen      -0.831522
# pencil    0.210819
# paper    -0.119523
# dtype: float64

# %% [markdown]
# ##**“Not a Number” Data**

# %%
# assigning a NaN Value using np.NaN.
ser = pd.Series([0, 1, 2, np.NaN, 9], index=['red', 'blue', 'purple', 'brown', 'black'])
ser
# Out:
# red       0.0
# blue      1.0
# purple    2.0
# brown     NaN
# black     9.0
# dtype: float64

# %%
ser['brown'] = None
ser
# Out:
# red       0.0
# blue      1.0
# purple    2.0
# brown     NaN
# black     9.0
# dtype: float64

# %%
# Filtering Out NaN Values.
# dropna() drop the NaN row.
ser.dropna()
# Out:
# red       0.0
# blue      1.0
# purple    2.0
# black     9.0
# dtype: float64

# %%
# notnull() for selecting not null values.
ser[ser.notnull()]
# Out:
# red       0.0
# blue      1.0
# purple    2.0
# black     9.0
# dtype: float64

# %%
frame3 = pd.DataFrame([[6,np.nan,6],[np.nan,np.nan,np.nan],[2,np.nan,5]],
index = ['blue','green','red'],
columns = ['ball','mug','pen'])
frame3
# Out:
#        ball  mug  pen
# blue    6.0  NaN  6.0
# green   NaN  NaN  NaN
# red     2.0  NaN  5.0

# %%
frame3.dropna()
# Out:
# Empty DataFrame
# Columns: [ball, mug, pen]
# Index: []

# %% [markdown]
# dropna() disappear entire row and columns to avoid this use "how" option.

# %%
frame3.dropna(how='all')
# Out:
#       ball  mug  pen
# blue   6.0  NaN  6.0
# red    2.0  NaN  5.0

# %% [markdown]
# ***Filling in NaN Occurrences***

# %%
frame3.fillna(0)
# Out:
#        ball  mug  pen
# blue    6.0  0.0  6.0
# green   0.0  0.0  0.0
# red     2.0  0.0  5.0

# %%
frame3.fillna({'ball': 1, 'mug': 0, 'pen': 99})
# Out:
#        ball  mug   pen
# blue    6.0  0.0   6.0
# green   1.0  0.0  99.0
# red     2.0  0.0   5.0

# %% [markdown]
# ##**Reading Data in CSV or Text Files**

# %%
import pandas as pd
csvframe = pd.read_csv('a.csv')
csvframe
# Out:
#        Year  ...                             Industry_code_ANZSIC06
# 0      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 1      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 2      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 3      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 4      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# ...     ...  ...                                                ...
# 19812  2016  ...         ANZSIC06 groups C211, C212, C213, and C214
# 19813  2016  ...         ANZSIC06 groups C211, C212, C213, and C214
# 19814  2016  ...         ANZSIC06 groups C211, C212, C213, and C214
# 19815  2016  ...         ANZSIC06 groups C211, C212, C213, and C214
# 19816  2016  ...                                                NaN
#
# [19817 rows x 10 columns]

# %%
# reading csv file using read_table().
from pandas.io.parsers import read_table
read_table('a.csv', sep=',')
# Out:
#        Year  ...                             Industry_code_ANZSIC06
# 0      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 1      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 2      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 3      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 4      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# ...     ...  ...                                                ...
# 37075  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37076  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37077  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37078  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37079  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [37080 rows x 10 columns]

# %%
pd.read_csv('a.csv', header=None)
# Out:
#           0  ...                                                  9
# 0      Year  ...                             Industry_code_ANZSIC06
# 1      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 2      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 3      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 4      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# ...     ...  ...                                                ...
# 37076  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37077  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37078  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37079  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37080  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [37081 rows x 10 columns]

# %%
# change the column name
pd.read_csv('a.csv', names=['red', 'white', 'blue', 'black', 'purple', 'pink', 'yellow', 'brown', 'green', 'orange'])
# Out:
#         red  ...                                             orange
# 0      Year  ...                             Industry_code_ANZSIC06
# 1      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 2      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 3      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 4      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# ...     ...  ...                                                ...
# 37076  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37077  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37078  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37079  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37080  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [37081 rows x 10 columns]

# %%
pd.read_csv('a.csv', sep=',', skiprows=[0, 1, 3, 6])
# Out:
#        2020  ... ANZSIC06 divisions A-S (excluding classes K6330, L6711, O7552, O760, O771, O772, S9540, S9601, S9602, and S9603)
# 0      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 1      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 2      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 3      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# 4      2020  ...  ANZSIC06 divisions A-S (excluding classes K633...
# ...     ...  ...                                                ...
# 37071  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37072  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37073  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37074  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 37075  2013  ...  ANZSIC06 groups C111, C112, C113, C114, C115, ...
#
# [37076 rows x 10 columns]
